# %% [markdown]
# # Model Mutation
#
# `model.set(...)` and `model.select(...).set(...)` apply explicit schema mutations to selected nodes. Use this when a base schema is right, but a specific workflow needs different masking, targets, embeddings, or serving behavior.
#
# Common mutations:
#
# | Mutation | Purpose |
# | --- | --- |
# | `target=True` | Withhold a field and decode it as a supervised target. |
# | `p_mask=...` | Randomly hide values for self-supervised reconstruction. |
# | `p_prune=...` | Remove whole field instances from input. |
# | `embed=True` | Return embeddings from a selected node. |
# | `target=False` | Keep a field in the schema while omitting it from serving requests. |

# %% [markdown]
# Start with a plain model. The species field is already a target, but the rest of the schema has no masking or embedding behavior yet.

# %%
from loguru import logger
from rich.pretty import pprint

import json2vec as j2v

logger.remove()

# %%
model = j2v.Model.from_schema(
    j2v.Number("sepal_length"),
    j2v.Number("petal_length"),
    j2v.Category("species", target=True, max_vocab_size=4),
    d_model=16,
    n_layers=1,
    n_heads=4,
)

# %% [markdown]
# Predicates are composable. Here, the example selects all numbers, all categories except the target, the target itself, and finally the root record node. Keep broad selectors visible by plotting the model and checking `last_mutation` before trusting them in a larger workflow.

# %%
numbers = j2v.where("type") == "number"
categories = j2v.where("type") == "category"
targets = j2v.where("name") == "species"

_ = model.set(numbers, p_mask=0.15)
_ = model.set(categories & ~targets, p_mask=0.05)
_ = model.set(targets, target=True)
_ = model.select(j2v.where("name") == "record").set(embed=True)

# %% [markdown]
# Plot after mutation to verify the final schema state. This is usually faster than reading nested configuration objects by hand.

# %%
model.plot(detail=True)
# Out:
# ╭──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                                                                      │
# │  JSON2Vec                                                             d_model  16                                    │
# │  Model                                                                 params  18,153                                │
# │  Schema map                                                            arrays  1                                     │
# │                                                                        fields  3                                     │
# │                                                                       targets  1                                     │
# │                                                                        embeds  1                                     │
# │                                                                         batch  1                                     │
# │                                                                         heads  4                                     │
# │                                                                                                                      │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Schema
# record [array] embed 6,608 params
# record
# attention=mha  max_length=1  n_outputs=1  n_layers=1  n_heads=4  embed=True  n_linear=1
# ├── sepal_length [number] 3,943 params
# │   record/sepal_length
# │   query=[*].sepal_length  pooling=query  objective=mae  weight=1.0  n_heads=4  p_mask=0.15  n_linear=1  jitter=0.0
# │   n_bands=8  offset=4
# │   └── details
# │       ├── state
# │       │   mean: 0.0
# │       │   variance: 1.0
# │       │   std_dev: 1.0000050067901611
# │       │   count: 0
# │       └── counter
# │           size: 5
# │           is_full: False
# │           counts: [1, 1, 1, 1, 1]
# ├── petal_length [number] 3,943 params
# │   record/petal_length
# │   query=[*].petal_length  pooling=query  objective=mae  weight=1.0  n_heads=4  p_mask=0.15  n_linear=1  jitter=0.0
# │   n_bands=8  offset=4
# │   └── details
# │       ├── state
# │       │   mean: 0.0
# │       │   variance: 1.0
# │       │   std_dev: 1.0000050067901611
# │       │   count: 0
# │       └── counter
# │           size: 5
# │           is_full: False
# │           counts: [1, 1, 1, 1, 1]
# └── species [category] target 3,659 params
#     record/species
#     query=[*].species  pooling=query  max_vocab_size=4  topk=[]  weight=1.0  n_heads=4  p_prune=1.0  n_linear=1
#     n_bands=8  p_unavailable=0.01
#     └── details
#         ├── state
#         │   vocabulary_size: 0
#         │   vocabulary: []
#         ├── counters.state
#         │   size: 5
#         │   is_full: False
#         │   counts: [1, 1, 1, 1, 1]
#         └── counters.content
#             size: 5
#             is_full: False
#             counts: [1, 1, 1, 1, 1]

# %% [markdown]
# Every mutation records what changed. `last_mutation` is useful in notebooks and tests when you want to confirm a broad selector touched only the intended nodes.

# %%
pprint(model.hyperparameters.last_mutation)
# Out:
# MutationResult(
# │   operation_id='7db73934e26d4a8198b43d25a8f3d1ff',
# │   parent_operation_id=None,
# │   action='set',
# │   matched=1,
# │   updated=1,
# │   skipped=0,
# │   changes=(MutationChange(node='record', field='embed', old=False, new=True, action='set'),)
# )
